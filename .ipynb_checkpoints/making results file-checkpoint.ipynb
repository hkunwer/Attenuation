# %%
import pandas as pd

# Create a DataFrame with specified column headers
data = {
    "station name": [],
    "distance": [],
    "event": [],
    "location": [],
    "magnitude": [],
    "mag type": [],
    "max amplitude": [],
    "frequency band": []
}

df_ALL = pd.DataFrame(data)

# Specify the filename for the .pkl file
pkl_filename = 'ResultsTest.pkl'

# Save the DataFrame to a .pkl file
df_ALL.to_pickle(pkl_filename)

print(f'Data saved to {pkl_filename}')
# Out:
# Data saved to ResultsTest.pkl

# %%
import pandas as pd

# Specify the filename of the .pkl file you want to read
pkl_filename = 'Results.pkl'

# Read the .pkl file into a DataFrame
df = pd.read_pickle(pkl_filename)

# Now, 'df' contains the data from the .pkl file

# You can access and manipulate the DataFrame as needed
df
# Out:
#    station name    distance                        event  \
# 0         R54B1  451.594251  2022-01-28T21:50:26.444000Z
# 1         RD4D8  233.711186  2022-01-28T21:50:26.444000Z
# 2         R54B1  451.594251  2022-01-28T21:50:26.444000Z
# 3         RD4D8  233.711186  2022-01-28T21:50:26.444000Z
# 4         R54B1  451.594251  2022-01-28T21:50:26.444000Z
# 5         RD4D8  233.711186  2022-01-28T21:50:26.444000Z
# 6         R54B1  451.594251  2022-01-28T21:50:26.444000Z
# 7         RD4D8  233.711186  2022-01-28T21:50:26.444000Z
# 8         R54B1  451.594251  2022-01-28T21:50:26.444000Z
# 9         RD4D8  233.711186  2022-01-28T21:50:26.444000Z
# 10        R0306  118.491655  2022-01-27T14:59:20.922000Z
# 11        R4EEE  366.222784  2022-01-27T14:59:20.922000Z
# 12        RA887  187.731814  2022-01-27T14:59:20.922000Z
# 13        R0306  118.491655  2022-01-27T14:59:20.922000Z
# 14        R4EEE  366.222784  2022-01-27T14:59:20.922000Z
# ...
